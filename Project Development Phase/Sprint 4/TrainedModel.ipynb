# %%
from tensorflow.keras.models import load_model
from skimage.transform import resize

# %%
import numpy as np

# %%
import cv2

# %%
model = load_model('body.h5')

# %%
def detect(frame):
  img = cv2.resize(frame,(224,224))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

  if(np.max(img)>1):
    img = img/255.0
  img = np.array([img])
  prediction = model.predict(img)
  label = ["front","rear","side"]
  preds = label[np.argmax(prediction)]
  return preds

# %%
from PIL import Image

# %%
Image.open("car.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x400 at 0x21282BD50A0>

# %%
data = "car.jpg"
image = cv2.imread(data)
print(detect(image))
# Out:
# 1/1 [==============================] - 4s 4s/step
# front

# %%
model = load_model('level.h5')

# %%
def detect(frame):
  img = cv2.resize(frame,(224,224))
  img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

  if(np.max(img)>1):
    img = img/255.0
  img = np.array([img])
  prediction = model.predict(img)
  label = ["minor","moderate","severe"]
  preds = label[np.argmax(prediction)]
  return preds

# %%
from PIL import Image

# %%
Image.open("car.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=550x400 at 0x2128335DC10>

# %%
data = "car.jpg"
image = cv2.imread(data)
print(detect(image))
# Out:
# 1/1 [==============================] - 1s 1s/step
# severe
